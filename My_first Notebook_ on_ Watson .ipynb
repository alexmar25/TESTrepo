# %% [markdown]
# # My jupyter Notebook on IBM Watson

# %% [markdown]
# <B>Alex Martinez<B>

# %% [markdown]
# im curretly working as a Graphic designer but i have been drawn to Data science for the past two years ans i would like to onde day be a data science idealy on the finance side .

# %% [markdown]
# <i>I am interested in data science because i have  always been a curious person. I like to predict things and i like graphics i like to get to the bottom of things. </i>

# %% [markdown]
# ### It must be executed and must display an output

# %%
hello =1+1
print(hello)
# Out:
# 2

# %% [markdown]
# #didnt quite get this quetion
# - one
# - two
# - three
# - four
# - five

# %% [markdown]
# <a href='#the_destination'>IBM.com</a>
